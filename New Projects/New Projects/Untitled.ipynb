# %%
import pandas as pd
# Out:
# C:\Users\TEMP.DSLSERVER.001\AppData\Local\Temp\ipykernel_9844\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data =  pd.read_csv('../pl.csv')

# %%
data
# Out:
#                      team_name              common_name     season  country  \
# 0                   Arsenal FC                  Arsenal  2018/2019  England
# 1         Tottenham Hotspur FC        Tottenham Hotspur  2018/2019  England
# 2           Manchester City FC          Manchester City  2018/2019  England
# 3            Leicester City FC           Leicester City  2018/2019  England
# 4            Crystal Palace FC           Crystal Palace  2018/2019  England
# 5                   Everton FC                  Everton  2018/2019  England
# 6                   Burnley FC                  Burnley  2018/2019  England
# 7               Southampton FC              Southampton  2018/2019  England
# 8              AFC Bournemouth          AFC Bournemouth  2018/2019  England
# 9         Manchester United FC        Manchester United  2018/2019  England
# 10                Liverpool FC                Liverpool  2018/2019  England
# ...

# %%
data['team_name']
# Out:
# 0                     Arsenal FC
# 1           Tottenham Hotspur FC
# 2             Manchester City FC
# 3              Leicester City FC
# 4              Crystal Palace FC
# 5                     Everton FC
# 6                     Burnley FC
# 7                 Southampton FC
# 8                AFC Bournemouth
# 9           Manchester United FC
# 10                  Liverpool FC
# 11                    Chelsea FC
# 12            West Ham United FC
# 13                    Watford FC
# 14           Newcastle United FC
# 15               Cardiff City FC
# 16                     Fulham FC
# 17     Brighton & Hove Albion FC
# 18          Huddersfield Town FC
# 19    Wolverhampton Wanderers FC
# Name: team_name, dtype: object

# %%
# Counting the Teams present inside the Premier League

# %%
data['team_name'].value_counts()
print(f'Total Teams Present inside the Premier League : {data.team_name.count()}')
# Out:
# Total Teams Present inside the Premier League : 20

# %%
data.describe(include = "all")
# Out:
#          team_name common_name     season  country  matches_played  \
# count           20          20         20       20            20.0
# unique          20          20          1        2             NaN
# top     Arsenal FC     Arsenal  2018/2019  England             NaN
# freq             1           1         20       19             NaN
# mean           NaN         NaN        NaN      NaN            38.0
# std            NaN         NaN        NaN      NaN             0.0
# min            NaN         NaN        NaN      NaN            38.0
# 25%            NaN         NaN        NaN      NaN            38.0
# 50%            NaN         NaN        NaN      NaN            38.0
# 75%            NaN         NaN        NaN      NaN            38.0
# max            NaN         NaN        NaN      NaN            38.0
#
#         matches_played_home  matches_played_away  suspended_matches  \
# count                  20.0                 20.0               20.0
# ...

# %%
data[data['wins'] > 20].sort_values('wins',ascending=False)
# Out:
#                team_name        common_name     season  country  \
# 2     Manchester City FC    Manchester City  2018/2019  England
# 10          Liverpool FC          Liverpool  2018/2019  England
# 1   Tottenham Hotspur FC  Tottenham Hotspur  2018/2019  England
# 0             Arsenal FC            Arsenal  2018/2019  England
# 11            Chelsea FC            Chelsea  2018/2019  England
#
#     matches_played  matches_played_home  matches_played_away  \
# 2               38                   19                   19
# 10              38                   19                   19
# 1               38                   19                   19
# 0               38                   19                   19
# 11              38                   19                   19
#
#     suspended_matches  wins  wins_home  ...  goals_conceded_min_61_to_70  \
# 2                   0    32         18  ...                            4
# ...

# %%
data[data['team_name'] == 'Manchester City FC']
# Out:
#             team_name      common_name     season  country  matches_played  \
# 2  Manchester City FC  Manchester City  2018/2019  England              38
#
#    matches_played_home  matches_played_away  suspended_matches  wins  \
# 2                   19                   19                  0    32
#
#    wins_home  ...  goals_conceded_min_61_to_70  goals_conceded_min_71_to_80  \
# 2         18  ...                            4                            2
#
#    goals_conceded_min_81_to_90  draw_percentage_overall  draw_percentage_home  \
# 2                            3                        5                     0
#
#    draw_percentage_away  loss_percentage_ovearll  loss_percentage_home  \
# 2                    11                       11                     5
#
#    loss_percentage_away  over145_corners_percentage
# 2                    16                           5
#
# [1 rows x 293 columns]
